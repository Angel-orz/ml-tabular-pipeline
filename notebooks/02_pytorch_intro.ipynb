# %% [markdown]
# ### Pytorch

# %%
import torch

print(f"PyTorch 版本: {torch.__version__}")
# Out:
# PyTorch 版本: 2.2.2

# %%
x = torch.tensor([1,2,3])
print(x)
# Out:
# tensor([1, 2, 3])

# %%
x = torch.rand(3,3)
print(x)
print(x.shape)
# Out:
# tensor([[0.5557, 0.4389, 0.5360],
#         [0.0140, 0.4767, 0.8471],
#         [0.9443, 0.5488, 0.0888]])
# torch.Size([3, 3])
