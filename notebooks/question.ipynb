# %% [markdown]
# ### Day 4
#
# Today I prepared the dataset for machine learning training.
#
# I separated the features and the target variable.
#
# Then I split the dataset into training and testing sets.
#
# The training set is used to train the model.
#
# The test set is used to evaluate the model on unseen data.

# %% [markdown]
# #### Why do we need a test set?
# The test set is used to evaluate how well the model generalizes to unseen data.

# %% [markdown]
# #### What is data leakage?
# Train/Test Split
# ↓
# 仅用Train拟合
# ↓
# 应用到Test

# %% [markdown]
# #### Why do we use random_state?
#
# To make the experiment reproducible.

# %% [markdown]
# #### Why do we need train/test split?
# To evaluate the model on unseen data

# %% [markdown]
# ### Day 6
# Today I trained my first machine learning model.
#
# I used Linear Regression to predict house prices.
#
# The model was trained on the training dataset.
#
# After training, I evaluated the model using RMSE.
#
# The lower the RMSE, the better the model performance.

# %% [markdown]
# Deep learning is a subset of machine learning.
#
# It uses neural networks with multiple layers.
#
# PyTorch is currently the most popular deep learning framework.
#
# TensorFlow is widely used in production environments.
#
# Many modern AI systems are based on transformer architectures.

# %% [markdown]
# #### What does fit() do?
# fit() learns patterns from training data and estimates model parameters.

# %% [markdown]
# RMSE measures prediction error. smaller is better

# %% [markdown]
# 3
