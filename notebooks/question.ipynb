# %% [markdown]
# ## Day 4
#
# Today I prepared the dataset for machine learning training.
#
# I separated the features and the target variable.
#
# Then I split the dataset into training and testing sets.
#
# The training set is used to train the model.
#
# The test set is used to evaluate the model on unseen data.

# %% [markdown]
# ### Why do we need a test set?
# The test set is used to evaluate how well the model generalizes to unseen data.

# %% [markdown]
# ### What is data leakage?
# Train/Test Split
# ↓
# 仅用Train拟合
# ↓
# 应用到Test

# %% [markdown]
# ### Why do we use random_state?
#
# To make the experiment reproducible.

# %% [markdown]
# ### Why do we need train/test split?
# To evaluate the model on unseen data
